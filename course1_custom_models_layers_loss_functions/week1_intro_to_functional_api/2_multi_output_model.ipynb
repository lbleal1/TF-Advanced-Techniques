# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# # Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2

def norm(x):
  return (x - train_stats['mean']) / train_stats['std']

# bivariate data viz - y_true vs y_pred
def plot_diff(y_true, y_pred, title=''):
  plt.scatter(y_true, y_pred)
  plt.plot([-100, 100], [-100, 100]) # plots a straight line with same x,y coords

  plt.title(title)
  plt.xlabel('True Values')
  plt.ylabel('Predictions')

  plt.axis('equal') # changes limits of x or y axis so that equal increments of x and y have the same length
  plt.axis('square') # changes the limit ranges (xmax-xmin) and (ymax-ymin) of the x and y axes to be the same, and have the same scaling, resulting in a square plot
  
  
  plt.xlim(plt.xlim()) 
  plt.ylim(plt.ylim())

  plt.show()

def plot_metrics(metric_name, title, ylim=5):
  plt.plot(history.history[metric_name], color= 'blue', label = metric_name)
  plt.plot(history.history['val_' + metric_name], color= 'green', label = 'val_' + metric_name)

  plt.title(title)
  plt.ylim(0, ylim)
  plt.legend()

  plt.show()

# %% [markdown]
# # Prepare the Data
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# # Model
#
# Changes for multi-output models:
# * in Model() class: `outputs=[y1_output, y2_output]`
# * model.compile() :
#   * `loss = {'y1_output': 'mse', 'y2_output': 'mse'}`
#   * ```
#      metrics = {'y1_output': tf.keras.metrics.RootMeanSquaredError(),
#                 'y2_output': tf.keras.metrics.RootMeanSquaredError()}
#     ```

# %%
# layers

input_layer = keras.layers.Input( shape=(len(train.columns), ) )
first_dense = keras.layers.Dense(units = '128', activation = 'relu')(input_layer)
second_dense = keras.layers.Dense(units='128', activation = 'relu')(first_dense)

y1_output = Dense(units ='1', name = 'y1_output')(second_dense)
third_dense = Dense(units = '64', activation = 'relu')(second_dense)

y2_output = Dense(units = '1', name = 'y2_output')(third_dense)

model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.SGD(lr=0.001)
model.compile(
              optimizer = optimizer,
              loss = {'y1_output': 'mse', 'y2_output': 'mse'},
              metrics = { 'y1_output': keras.metrics.RootMeanSquaredError(),
                          'y2_output': keras.metrics.RootMeanSquaredError()
                        }
)

# %%
type(train_Y)
# Out:
# tuple

# %%
history = model.fit(
    norm_train_X,
    train_Y,
    epochs = 500,
    batch_size = 10,
    validation_data = (norm_test_X, test_Y)
)
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 7ms/step - loss: 537.0645 - y1_output_loss: 256.8423 - y2_output_loss: 280.2222 - y1_output_root_mean_squared_error: 15.3627 - y2_output_root_mean_squared_error: 16.0663 - val_loss: 46.8057 - val_y1_output_loss: 18.2465 - val_y2_output_loss: 28.5592 - val_y1_output_root_mean_squared_error: 4.2716 - val_y2_output_root_mean_squared_error: 5.3441
# Epoch 2/500
# 62/62 [==============================] - 0s 2ms/step - loss: 38.9446 - y1_output_loss: 14.2143 - y2_output_loss: 24.7303 - y1_output_root_mean_squared_error: 3.7420 - y2_output_root_mean_squared_error: 4.9077 - val_loss: 26.2234 - val_y1_output_loss: 11.5750 - val_y2_output_loss: 14.6484 - val_y1_output_root_mean_squared_error: 3.4022 - val_y2_output_root_mean_squared_error: 3.8273
# Epoch 3/500
# 62/62 [==============================] - 0s 2ms/step - loss: 26.5324 - y1_output_loss: 10.7094 - y2_output_loss: 15.8230 - y1_output_root_mean_squared_error: 3.2608 - y2_output_root_mean_squared_error: 3.9702 - val_loss: 47.0028 - val_y1_output_loss: 11.8400 - val_y2_output_loss: 35.1627 - val_y1_output_root_mean_squared_error: 3.4409 - val_y2_output_root_mean_squared_error: 5.9298
# Epoch 4/500
# 62/62 [==============================] - 0s 2ms/step - loss: 22.7648 - y1_output_loss: 9.3064 - y2_output_loss: 13.4584 - y1_output_root_mean_squared_error: 3.0491 - y2_output_root_mean_squared_error: 3.6650 - val_loss: 23.4594 - val_y1_output_loss: 9.5825 - val_y2_output_loss: 13.8769 - val_y1_output_root_mean_squared_error: 3.0956 - val_y2_output_root_mean_squared_error: 3.7252
# Epoch 5/500
# 62/62 [==============================] - 0s 2ms/step - loss: 21.9649 - y1_output_loss: 8.1169 - y2_output_loss: 13.8480 - y1_output_root_mean_squared_error: 2.8466 - y2_output_root_mean_squared_error: 3.7137 - val_loss: 38.3021 - val_y1_output_loss: 14.4399 - val_y2_output_loss: 23.8623 - val_y1_output_root_mean_squared_error: 3.8000 - val_y2_output_root_mean_squared_error: 4.8849
# Epoch 6/500
# 62/62 [==============================] - 0s 2ms/step - loss: 25.0625 - y1_output_loss: 9.1517 - y2_output_loss: 15.9107 - y1_output_root_mean_squared_error: 3.0227 - y2_output_root_mean_squared_error: 3.9786 - val_loss: 41.1367 - val_y1_output_loss: 13.7453 - val_y2_output_loss: 27.3915 - val_y1_output_root_mean_squared_error: 3.7075 - val_y2_output_root_mean_squared_error: 5.2337
# Epoch 7/500
# 62/62 [==============================] - 0s 2ms/step - loss: 26.0441 - y1_output_loss: 10.1187 - y2_output_loss: 15.9254 - y1_output_root_mean_squared_error: 3.1790 - y2_output_root_mean_squared_error: 3.9867 - val_loss: 29.3273 - val_y1_output_loss: 9.2491 - val_y2_output_loss: 20.0782 - val_y1_output_root_mean_squared_error: 3.0412 - val_y2_output_root_mean_squared_error: 4.4809
# Epoch 8/500
# 62/62 [==============================] - 0s 2ms/step - loss: 29.4979 - y1_output_loss: 9.8132 - y2_output_loss: 19.6847 - y1_output_root_mean_squared_error: 3.1191 - y2_output_root_mean_squared_error: 4.3923 - val_loss: 20.8624 - val_y1_output_loss: 8.7550 - val_y2_output_loss: 12.1074 - val_y1_output_root_mean_squared_error: 2.9589 - val_y2_output_root_mean_squared_error: 3.4796
# Epoch 9/500
# 62/62 [==============================] - 0s 2ms/step - loss: 20.1587 - y1_output_loss: 7.9163 - y2_output_loss: 12.2424 - y1_output_root_mean_squared_error: 2.8104 - y2_output_root_mean_squared_error: 3.4838 - val_loss: 20.6058 - val_y1_output_loss: 8.8364 - val_y2_output_loss: 11.7694 - val_y1_output_root_mean_squared_error: 2.9726 - val_y2_output_root_mean_squared_error: 3.4307
# Epoch 10/500
# 62/62 [==============================] - 0s 2ms/step - loss: 28.4979 - y1_output_loss: 9.0425 - y2_output_loss: 19.4554 - y1_output_root_mean_squared_error: 3.0012 - y2_output_root_mean_squared_error: 4.3743 - val_loss: 31.2151 - val_y1_output_loss: 10.1429 - val_y2_output_loss: 21.0722 - val_y1_output_root_mean_squared_error: 3.1848 - val_y2_output_root_mean_squared_error: 4.5904
# Epoch 11/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.9062 - y1_output_loss: 7.7381 - y2_output_loss: 12.1681 - y1_output_root_mean_squared_error: 2.7806 - y2_output_root_mean_squared_error: 3.4843 - val_loss: 66.5837 - val_y1_output_loss: 16.6717 - val_y2_output_loss: 49.9120 - val_y1_output_root_mean_squared_error: 4.0831 - val_y2_output_root_mean_squared_error: 7.0648
# Epoch 12/500
# 62/62 [==============================] - 0s 2ms/step - loss: 34.3820 - y1_output_loss: 11.2098 - y2_output_loss: 23.1723 - y1_output_root_mean_squared_error: 3.2939 - y2_output_root_mean_squared_error: 4.6657 - val_loss: 19.1686 - val_y1_output_loss: 8.0678 - val_y2_output_loss: 11.1008 - val_y1_output_root_mean_squared_error: 2.8404 - val_y2_output_root_mean_squared_error: 3.3318
# Epoch 13/500
# 62/62 [==============================] - 0s 2ms/step - loss: 26.4972 - y1_output_loss: 9.4743 - y2_output_loss: 17.0229 - y1_output_root_mean_squared_error: 3.0745 - y2_output_root_mean_squared_error: 4.1005 - val_loss: 35.7588 - val_y1_output_loss: 10.0783 - val_y2_output_loss: 25.6805 - val_y1_output_root_mean_squared_error: 3.1746 - val_y2_output_root_mean_squared_error: 5.0676
# Epoch 14/500
# 62/62 [==============================] - 0s 2ms/step - loss: 20.3478 - y1_output_loss: 7.9209 - y2_output_loss: 12.4269 - y1_output_root_mean_squared_error: 2.8099 - y2_output_root_mean_squared_error: 3.5219 - val_loss: 28.7117 - val_y1_output_loss: 10.9441 - val_y2_output_loss: 17.7675 - val_y1_output_root_mean_squared_error: 3.3082 - val_y2_output_root_mean_squared_error: 4.2152
# Epoch 15/500
# 62/62 [==============================] - 0s 2ms/step - loss: 17.5633 - y1_output_loss: 6.9675 - y2_output_loss: 10.5958 - y1_output_root_mean_squared_error: 2.6351 - y2_output_root_mean_squared_error: 3.2455 - val_loss: 45.2558 - val_y1_output_loss: 11.1602 - val_y2_output_loss: 34.0956 - val_y1_output_root_mean_squared_error: 3.3407 - val_y2_output_root_mean_squared_error: 5.8391
# Epoch 16/500
# 62/62 [==============================] - 0s 2ms/step - loss: 18.0992 - y1_output_loss: 7.1093 - y2_output_loss: 10.9899 - y1_output_root_mean_squared_error: 2.6644 - y2_output_root_mean_squared_error: 3.2811 - val_loss: 31.5935 - val_y1_output_loss: 9.0687 - val_y2_output_loss: 22.5247 - val_y1_output_root_mean_squared_error: 3.0114 - val_y2_output_root_mean_squared_error: 4.7460
# Epoch 17/500
# 62/62 [==============================] - 0s 2ms/step - loss: 21.3978 - y1_output_loss: 6.6955 - y2_output_loss: 14.7023 - y1_output_root_mean_squared_error: 2.5793 - y2_output_root_mean_squared_error: 3.7725 - val_loss: 18.1227 - val_y1_output_loss: 7.6745 - val_y2_output_loss: 10.4482 - val_y1_output_root_mean_squared_error: 2.7703 - val_y2_output_root_mean_squared_error: 3.2324
# Epoch 18/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.2491 - y1_output_loss: 5.7959 - y2_output_loss: 9.4532 - y1_output_root_mean_squared_error: 2.3977 - y2_output_root_mean_squared_error: 3.0582 - val_loss: 17.2244 - val_y1_output_loss: 7.1826 - val_y2_output_loss: 10.0418 - val_y1_output_root_mean_squared_error: 2.6800 - val_y2_output_root_mean_squared_error: 3.1689
# Epoch 19/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.4016 - y1_output_loss: 5.9449 - y2_output_loss: 9.4567 - y1_output_root_mean_squared_error: 2.4267 - y2_output_root_mean_squared_error: 3.0558 - val_loss: 17.0828 - val_y1_output_loss: 7.2150 - val_y2_output_loss: 9.8678 - val_y1_output_root_mean_squared_error: 2.6861 - val_y2_output_root_mean_squared_error: 3.1413
# Epoch 20/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.8762 - y1_output_loss: 5.9526 - y2_output_loss: 7.9236 - y1_output_root_mean_squared_error: 2.4379 - y2_output_root_mean_squared_error: 2.8033 - val_loss: 32.5693 - val_y1_output_loss: 9.4689 - val_y2_output_loss: 23.1004 - val_y1_output_root_mean_squared_error: 3.0772 - val_y2_output_root_mean_squared_error: 4.8063
# Epoch 21/500
# 62/62 [==============================] - 0s 2ms/step - loss: 17.3338 - y1_output_loss: 6.6653 - y2_output_loss: 10.6686 - y1_output_root_mean_squared_error: 2.5745 - y2_output_root_mean_squared_error: 3.2472 - val_loss: 20.8454 - val_y1_output_loss: 9.7327 - val_y2_output_loss: 11.1127 - val_y1_output_root_mean_squared_error: 3.1197 - val_y2_output_root_mean_squared_error: 3.3336
# Epoch 22/500
# 62/62 [==============================] - 0s 2ms/step - loss: 16.3506 - y1_output_loss: 6.2329 - y2_output_loss: 10.1177 - y1_output_root_mean_squared_error: 2.4932 - y2_output_root_mean_squared_error: 3.1727 - val_loss: 16.2467 - val_y1_output_loss: 6.5754 - val_y2_output_loss: 9.6713 - val_y1_output_root_mean_squared_error: 2.5643 - val_y2_output_root_mean_squared_error: 3.1099
# Epoch 23/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.1611 - y1_output_loss: 5.7296 - y2_output_loss: 7.4315 - y1_output_root_mean_squared_error: 2.3915 - y2_output_root_mean_squared_error: 2.7235 - val_loss: 55.3897 - val_y1_output_loss: 17.3567 - val_y2_output_loss: 38.0330 - val_y1_output_root_mean_squared_error: 4.1661 - val_y2_output_root_mean_squared_error: 6.1671
# Epoch 24/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.8903 - y1_output_loss: 6.6930 - y2_output_loss: 9.1973 - y1_output_root_mean_squared_error: 2.5604 - y2_output_root_mean_squared_error: 3.0086 - val_loss: 15.0655 - val_y1_output_loss: 5.8851 - val_y2_output_loss: 9.1804 - val_y1_output_root_mean_squared_error: 2.4259 - val_y2_output_root_mean_squared_error: 3.0299
# Epoch 25/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.6216 - y1_output_loss: 4.5261 - y2_output_loss: 7.0954 - y1_output_root_mean_squared_error: 2.1217 - y2_output_root_mean_squared_error: 2.6589 - val_loss: 13.6828 - val_y1_output_loss: 5.5287 - val_y2_output_loss: 8.1542 - val_y1_output_root_mean_squared_error: 2.3513 - val_y2_output_root_mean_squared_error: 2.8556
# Epoch 26/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.4943 - y1_output_loss: 5.8526 - y2_output_loss: 9.6417 - y1_output_root_mean_squared_error: 2.4173 - y2_output_root_mean_squared_error: 3.1018 - val_loss: 13.2265 - val_y1_output_loss: 5.4227 - val_y2_output_loss: 7.8038 - val_y1_output_root_mean_squared_error: 2.3287 - val_y2_output_root_mean_squared_error: 2.7935
# Epoch 27/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.8246 - y1_output_loss: 5.2247 - y2_output_loss: 7.5999 - y1_output_root_mean_squared_error: 2.2811 - y2_output_root_mean_squared_error: 2.7222 - val_loss: 12.9010 - val_y1_output_loss: 4.9968 - val_y2_output_loss: 7.9043 - val_y1_output_root_mean_squared_error: 2.2353 - val_y2_output_root_mean_squared_error: 2.8115
# Epoch 28/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.5838 - y1_output_loss: 4.5222 - y2_output_loss: 8.0615 - y1_output_root_mean_squared_error: 2.1181 - y2_output_root_mean_squared_error: 2.8287 - val_loss: 19.7353 - val_y1_output_loss: 7.3676 - val_y2_output_loss: 12.3677 - val_y1_output_root_mean_squared_error: 2.7143 - val_y2_output_root_mean_squared_error: 3.5168
# Epoch 29/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.7862 - y1_output_loss: 4.8431 - y2_output_loss: 8.9431 - y1_output_root_mean_squared_error: 2.1957 - y2_output_root_mean_squared_error: 2.9879 - val_loss: 12.2632 - val_y1_output_loss: 4.9489 - val_y2_output_loss: 7.3144 - val_y1_output_root_mean_squared_error: 2.2246 - val_y2_output_root_mean_squared_error: 2.7045
# Epoch 30/500
# 62/62 [==============================] - 0s 2ms/step - loss: 12.7507 - y1_output_loss: 4.2726 - y2_output_loss: 8.4781 - y1_output_root_mean_squared_error: 2.0639 - y2_output_root_mean_squared_error: 2.9000 - val_loss: 23.0952 - val_y1_output_loss: 6.0622 - val_y2_output_loss: 17.0330 - val_y1_output_root_mean_squared_error: 2.4621 - val_y2_output_root_mean_squared_error: 4.1271
# Epoch 31/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.1190 - y1_output_loss: 3.9509 - y2_output_loss: 7.1681 - y1_output_root_mean_squared_error: 1.9853 - y2_output_root_mean_squared_error: 2.6711 - val_loss: 10.1870 - val_y1_output_loss: 3.9529 - val_y2_output_loss: 6.2341 - val_y1_output_root_mean_squared_error: 1.9882 - val_y2_output_root_mean_squared_error: 2.4968
# Epoch 32/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.5065 - y1_output_loss: 4.3229 - y2_output_loss: 6.1836 - y1_output_root_mean_squared_error: 2.0775 - y2_output_root_mean_squared_error: 2.4734 - val_loss: 34.3662 - val_y1_output_loss: 8.8328 - val_y2_output_loss: 25.5334 - val_y1_output_root_mean_squared_error: 2.9720 - val_y2_output_root_mean_squared_error: 5.0531
# Epoch 33/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.9652 - y1_output_loss: 4.6712 - y2_output_loss: 10.2940 - y1_output_root_mean_squared_error: 2.1583 - y2_output_root_mean_squared_error: 3.1944 - val_loss: 10.3603 - val_y1_output_loss: 3.8357 - val_y2_output_loss: 6.5246 - val_y1_output_root_mean_squared_error: 1.9585 - val_y2_output_root_mean_squared_error: 2.5543
# Epoch 34/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.6569 - y1_output_loss: 4.7009 - y2_output_loss: 8.9560 - y1_output_root_mean_squared_error: 2.1593 - y2_output_root_mean_squared_error: 2.9763 - val_loss: 10.5376 - val_y1_output_loss: 4.6079 - val_y2_output_loss: 5.9297 - val_y1_output_root_mean_squared_error: 2.1466 - val_y2_output_root_mean_squared_error: 2.4351
# Epoch 35/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.2291 - y1_output_loss: 3.6029 - y2_output_loss: 6.6262 - y1_output_root_mean_squared_error: 1.8958 - y2_output_root_mean_squared_error: 2.5686 - val_loss: 12.9228 - val_y1_output_loss: 4.5297 - val_y2_output_loss: 8.3931 - val_y1_output_root_mean_squared_error: 2.1283 - val_y2_output_root_mean_squared_error: 2.8971
# Epoch 36/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.6121 - y1_output_loss: 3.5270 - y2_output_loss: 6.0851 - y1_output_root_mean_squared_error: 1.8747 - y2_output_root_mean_squared_error: 2.4651 - val_loss: 10.1737 - val_y1_output_loss: 3.4901 - val_y2_output_loss: 6.6836 - val_y1_output_root_mean_squared_error: 1.8682 - val_y2_output_root_mean_squared_error: 2.5853
# Epoch 37/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.7928 - y1_output_loss: 2.5581 - y2_output_loss: 5.2347 - y1_output_root_mean_squared_error: 1.5906 - y2_output_root_mean_squared_error: 2.2851 - val_loss: 14.8396 - val_y1_output_loss: 4.4056 - val_y2_output_loss: 10.4340 - val_y1_output_root_mean_squared_error: 2.0989 - val_y2_output_root_mean_squared_error: 3.2302
# Epoch 38/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.3867 - y1_output_loss: 3.1775 - y2_output_loss: 6.2092 - y1_output_root_mean_squared_error: 1.7787 - y2_output_root_mean_squared_error: 2.4792 - val_loss: 21.1159 - val_y1_output_loss: 5.3733 - val_y2_output_loss: 15.7426 - val_y1_output_root_mean_squared_error: 2.3180 - val_y2_output_root_mean_squared_error: 3.9677
# Epoch 39/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.0345 - y1_output_loss: 3.1784 - y2_output_loss: 5.8561 - y1_output_root_mean_squared_error: 1.7783 - y2_output_root_mean_squared_error: 2.4116 - val_loss: 18.4932 - val_y1_output_loss: 4.0264 - val_y2_output_loss: 14.4668 - val_y1_output_root_mean_squared_error: 2.0066 - val_y2_output_root_mean_squared_error: 3.8035
# Epoch 40/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.5585 - y1_output_loss: 3.2001 - y2_output_loss: 5.3584 - y1_output_root_mean_squared_error: 1.7862 - y2_output_root_mean_squared_error: 2.3113 - val_loss: 15.8453 - val_y1_output_loss: 5.6281 - val_y2_output_loss: 10.2172 - val_y1_output_root_mean_squared_error: 2.3724 - val_y2_output_root_mean_squared_error: 3.1964
# Epoch 41/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.3052 - y1_output_loss: 3.0913 - y2_output_loss: 6.2139 - y1_output_root_mean_squared_error: 1.7482 - y2_output_root_mean_squared_error: 2.4721 - val_loss: 9.1898 - val_y1_output_loss: 3.5212 - val_y2_output_loss: 5.6685 - val_y1_output_root_mean_squared_error: 1.8765 - val_y2_output_root_mean_squared_error: 2.3809
# Epoch 42/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.7417 - y1_output_loss: 3.2849 - y2_output_loss: 4.4568 - y1_output_root_mean_squared_error: 1.8091 - y2_output_root_mean_squared_error: 2.1050 - val_loss: 7.4579 - val_y1_output_loss: 2.7757 - val_y2_output_loss: 4.6822 - val_y1_output_root_mean_squared_error: 1.6660 - val_y2_output_root_mean_squared_error: 2.1638
# Epoch 43/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.8533 - y1_output_loss: 2.6341 - y2_output_loss: 5.2192 - y1_output_root_mean_squared_error: 1.6156 - y2_output_root_mean_squared_error: 2.2815 - val_loss: 11.2334 - val_y1_output_loss: 3.1254 - val_y2_output_loss: 8.1081 - val_y1_output_root_mean_squared_error: 1.7679 - val_y2_output_root_mean_squared_error: 2.8475
# Epoch 44/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.4584 - y1_output_loss: 2.5673 - y2_output_loss: 4.8911 - y1_output_root_mean_squared_error: 1.5916 - y2_output_root_mean_squared_error: 2.2067 - val_loss: 7.8734 - val_y1_output_loss: 2.4733 - val_y2_output_loss: 5.4001 - val_y1_output_root_mean_squared_error: 1.5727 - val_y2_output_root_mean_squared_error: 2.3238
# Epoch 45/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.1553 - y1_output_loss: 2.8143 - y2_output_loss: 6.3410 - y1_output_root_mean_squared_error: 1.6730 - y2_output_root_mean_squared_error: 2.5042 - val_loss: 7.9912 - val_y1_output_loss: 2.6964 - val_y2_output_loss: 5.2949 - val_y1_output_root_mean_squared_error: 1.6421 - val_y2_output_root_mean_squared_error: 2.3011
# Epoch 46/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.8573 - y1_output_loss: 2.4703 - y2_output_loss: 5.3871 - y1_output_root_mean_squared_error: 1.5658 - y2_output_root_mean_squared_error: 2.3165 - val_loss: 14.4388 - val_y1_output_loss: 4.0710 - val_y2_output_loss: 10.3679 - val_y1_output_root_mean_squared_error: 2.0177 - val_y2_output_root_mean_squared_error: 3.2199
# Epoch 47/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.1560 - y1_output_loss: 2.7428 - y2_output_loss: 5.4132 - y1_output_root_mean_squared_error: 1.6524 - y2_output_root_mean_squared_error: 2.3057 - val_loss: 8.9197 - val_y1_output_loss: 3.2545 - val_y2_output_loss: 5.6652 - val_y1_output_root_mean_squared_error: 1.8040 - val_y2_output_root_mean_squared_error: 2.3802
# Epoch 48/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.7188 - y1_output_loss: 2.7859 - y2_output_loss: 4.9328 - y1_output_root_mean_squared_error: 1.6634 - y2_output_root_mean_squared_error: 2.2180 - val_loss: 10.9946 - val_y1_output_loss: 2.8315 - val_y2_output_loss: 8.1630 - val_y1_output_root_mean_squared_error: 1.6827 - val_y2_output_root_mean_squared_error: 2.8571
# Epoch 49/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.4455 - y1_output_loss: 2.9063 - y2_output_loss: 5.5392 - y1_output_root_mean_squared_error: 1.7000 - y2_output_root_mean_squared_error: 2.3491 - val_loss: 6.5157 - val_y1_output_loss: 2.0902 - val_y2_output_loss: 4.4256 - val_y1_output_root_mean_squared_error: 1.4457 - val_y2_output_root_mean_squared_error: 2.1037
# Epoch 50/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.3757 - y1_output_loss: 2.1277 - y2_output_loss: 4.2480 - y1_output_root_mean_squared_error: 1.4572 - y2_output_root_mean_squared_error: 2.0531 - val_loss: 6.2498 - val_y1_output_loss: 2.1249 - val_y2_output_loss: 4.1250 - val_y1_output_root_mean_squared_error: 1.4577 - val_y2_output_root_mean_squared_error: 2.0310
# Epoch 51/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.6488 - y1_output_loss: 2.7456 - y2_output_loss: 5.9033 - y1_output_root_mean_squared_error: 1.6523 - y2_output_root_mean_squared_error: 2.4021 - val_loss: 6.9082 - val_y1_output_loss: 2.3226 - val_y2_output_loss: 4.5856 - val_y1_output_root_mean_squared_error: 1.5240 - val_y2_output_root_mean_squared_error: 2.1414
# Epoch 52/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.2552 - y1_output_loss: 2.3160 - y2_output_loss: 4.9392 - y1_output_root_mean_squared_error: 1.5128 - y2_output_root_mean_squared_error: 2.2120 - val_loss: 11.1024 - val_y1_output_loss: 5.0715 - val_y2_output_loss: 6.0309 - val_y1_output_root_mean_squared_error: 2.2520 - val_y2_output_root_mean_squared_error: 2.4558
# Epoch 53/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.5677 - y1_output_loss: 1.9782 - y2_output_loss: 3.5894 - y1_output_root_mean_squared_error: 1.4043 - y2_output_root_mean_squared_error: 1.8886 - val_loss: 15.3962 - val_y1_output_loss: 3.4360 - val_y2_output_loss: 11.9603 - val_y1_output_root_mean_squared_error: 1.8536 - val_y2_output_root_mean_squared_error: 3.4584
# Epoch 54/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.1640 - y1_output_loss: 2.5322 - y2_output_loss: 4.6319 - y1_output_root_mean_squared_error: 1.5800 - y2_output_root_mean_squared_error: 2.1292 - val_loss: 14.1888 - val_y1_output_loss: 4.6408 - val_y2_output_loss: 9.5480 - val_y1_output_root_mean_squared_error: 2.1543 - val_y2_output_root_mean_squared_error: 3.0900
# Epoch 55/500
# 62/62 [==============================] - 0s 2ms/step - loss: 11.2120 - y1_output_loss: 3.3375 - y2_output_loss: 7.8744 - y1_output_root_mean_squared_error: 1.8155 - y2_output_root_mean_squared_error: 2.7816 - val_loss: 18.1109 - val_y1_output_loss: 6.8539 - val_y2_output_loss: 11.2571 - val_y1_output_root_mean_squared_error: 2.6180 - val_y2_output_root_mean_squared_error: 3.3552
# Epoch 56/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.2920 - y1_output_loss: 3.2050 - y2_output_loss: 6.0871 - y1_output_root_mean_squared_error: 1.7721 - y2_output_root_mean_squared_error: 2.4654 - val_loss: 9.2328 - val_y1_output_loss: 2.5611 - val_y2_output_loss: 6.6717 - val_y1_output_root_mean_squared_error: 1.6003 - val_y2_output_root_mean_squared_error: 2.5830
# Epoch 57/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.5621 - y1_output_loss: 2.0293 - y2_output_loss: 4.5327 - y1_output_root_mean_squared_error: 1.4205 - y2_output_root_mean_squared_error: 2.1194 - val_loss: 6.0381 - val_y1_output_loss: 2.0568 - val_y2_output_loss: 3.9813 - val_y1_output_root_mean_squared_error: 1.4341 - val_y2_output_root_mean_squared_error: 1.9953
# Epoch 58/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.8332 - y1_output_loss: 1.8794 - y2_output_loss: 3.9538 - y1_output_root_mean_squared_error: 1.3688 - y2_output_root_mean_squared_error: 1.9779 - val_loss: 8.6454 - val_y1_output_loss: 2.6150 - val_y2_output_loss: 6.0304 - val_y1_output_root_mean_squared_error: 1.6171 - val_y2_output_root_mean_squared_error: 2.4557
# Epoch 59/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.9440 - y1_output_loss: 3.3949 - y2_output_loss: 7.5491 - y1_output_root_mean_squared_error: 1.8316 - y2_output_root_mean_squared_error: 2.7299 - val_loss: 9.0270 - val_y1_output_loss: 2.9824 - val_y2_output_loss: 6.0446 - val_y1_output_root_mean_squared_error: 1.7270 - val_y2_output_root_mean_squared_error: 2.4586
# Epoch 60/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.6245 - y1_output_loss: 2.4976 - y2_output_loss: 6.1269 - y1_output_root_mean_squared_error: 1.5594 - y2_output_root_mean_squared_error: 2.4382 - val_loss: 8.0658 - val_y1_output_loss: 2.8565 - val_y2_output_loss: 5.2092 - val_y1_output_root_mean_squared_error: 1.6901 - val_y2_output_root_mean_squared_error: 2.2824
# Epoch 61/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.7236 - y1_output_loss: 1.9796 - y2_output_loss: 4.7439 - y1_output_root_mean_squared_error: 1.4049 - y2_output_root_mean_squared_error: 2.1759 - val_loss: 33.9212 - val_y1_output_loss: 6.9017 - val_y2_output_loss: 27.0196 - val_y1_output_root_mean_squared_error: 2.6271 - val_y2_output_root_mean_squared_error: 5.1980
# Epoch 62/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.4658 - y1_output_loss: 2.1508 - y2_output_loss: 5.3150 - y1_output_root_mean_squared_error: 1.4608 - y2_output_root_mean_squared_error: 2.2820 - val_loss: 9.3599 - val_y1_output_loss: 1.8602 - val_y2_output_loss: 7.4997 - val_y1_output_root_mean_squared_error: 1.3639 - val_y2_output_root_mean_squared_error: 2.7386
# Epoch 63/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.6307 - y1_output_loss: 1.8470 - y2_output_loss: 3.7838 - y1_output_root_mean_squared_error: 1.3566 - y2_output_root_mean_squared_error: 1.9332 - val_loss: 6.1067 - val_y1_output_loss: 1.5814 - val_y2_output_loss: 4.5253 - val_y1_output_root_mean_squared_error: 1.2575 - val_y2_output_root_mean_squared_error: 2.1273
# Epoch 64/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.6758 - y1_output_loss: 1.9051 - y2_output_loss: 3.7706 - y1_output_root_mean_squared_error: 1.3714 - y2_output_root_mean_squared_error: 1.9246 - val_loss: 49.5804 - val_y1_output_loss: 11.4302 - val_y2_output_loss: 38.1503 - val_y1_output_root_mean_squared_error: 3.3809 - val_y2_output_root_mean_squared_error: 6.1766
# Epoch 65/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.4935 - y1_output_loss: 4.9936 - y2_output_loss: 10.4998 - y1_output_root_mean_squared_error: 2.1369 - y2_output_root_mean_squared_error: 3.1101 - val_loss: 7.4012 - val_y1_output_loss: 1.5900 - val_y2_output_loss: 5.8113 - val_y1_output_root_mean_squared_error: 1.2609 - val_y2_output_root_mean_squared_error: 2.4107
# Epoch 66/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.9707 - y1_output_loss: 1.1065 - y2_output_loss: 2.8642 - y1_output_root_mean_squared_error: 1.0499 - y2_output_root_mean_squared_error: 1.6868 - val_loss: 4.9369 - val_y1_output_loss: 1.2808 - val_y2_output_loss: 3.6561 - val_y1_output_root_mean_squared_error: 1.1317 - val_y2_output_root_mean_squared_error: 1.9121
# Epoch 67/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.2462 - y1_output_loss: 1.4034 - y2_output_loss: 3.8429 - y1_output_root_mean_squared_error: 1.1772 - y2_output_root_mean_squared_error: 1.9462 - val_loss: 6.3232 - val_y1_output_loss: 1.8987 - val_y2_output_loss: 4.4244 - val_y1_output_root_mean_squared_error: 1.3779 - val_y2_output_root_mean_squared_error: 2.1034
# Epoch 68/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.9374 - y1_output_loss: 1.8100 - y2_output_loss: 4.1274 - y1_output_root_mean_squared_error: 1.3360 - y2_output_root_mean_squared_error: 2.0213 - val_loss: 13.9621 - val_y1_output_loss: 5.8647 - val_y2_output_loss: 8.0974 - val_y1_output_root_mean_squared_error: 2.4217 - val_y2_output_root_mean_squared_error: 2.8456
# Epoch 69/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.7204 - y1_output_loss: 1.5528 - y2_output_loss: 3.1677 - y1_output_root_mean_squared_error: 1.2440 - y2_output_root_mean_squared_error: 1.7763 - val_loss: 3.8122 - val_y1_output_loss: 1.1095 - val_y2_output_loss: 2.7027 - val_y1_output_root_mean_squared_error: 1.0533 - val_y2_output_root_mean_squared_error: 1.6440
# Epoch 70/500
# 62/62 [==============================] - 0s 2ms/step - loss: 7.1609 - y1_output_loss: 2.2075 - y2_output_loss: 4.9534 - y1_output_root_mean_squared_error: 1.4626 - y2_output_root_mean_squared_error: 2.1918 - val_loss: 6.6830 - val_y1_output_loss: 1.5894 - val_y2_output_loss: 5.0936 - val_y1_output_root_mean_squared_error: 1.2607 - val_y2_output_root_mean_squared_error: 2.2569
# Epoch 71/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.8789 - y1_output_loss: 0.9897 - y2_output_loss: 2.8892 - y1_output_root_mean_squared_error: 0.9926 - y2_output_root_mean_squared_error: 1.6911 - val_loss: 3.8139 - val_y1_output_loss: 0.9597 - val_y2_output_loss: 2.8542 - val_y1_output_root_mean_squared_error: 0.9796 - val_y2_output_root_mean_squared_error: 1.6894
# Epoch 72/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.8068 - y1_output_loss: 1.0533 - y2_output_loss: 3.7535 - y1_output_root_mean_squared_error: 1.0236 - y2_output_root_mean_squared_error: 1.9319 - val_loss: 5.9410 - val_y1_output_loss: 0.9588 - val_y2_output_loss: 4.9822 - val_y1_output_root_mean_squared_error: 0.9792 - val_y2_output_root_mean_squared_error: 2.2321
# Epoch 73/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.0518 - y1_output_loss: 0.9243 - y2_output_loss: 3.1276 - y1_output_root_mean_squared_error: 0.9597 - y2_output_root_mean_squared_error: 1.7635 - val_loss: 4.3479 - val_y1_output_loss: 0.9806 - val_y2_output_loss: 3.3673 - val_y1_output_root_mean_squared_error: 0.9903 - val_y2_output_root_mean_squared_error: 1.8350
# Epoch 74/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.1191 - y1_output_loss: 1.5669 - y2_output_loss: 3.5522 - y1_output_root_mean_squared_error: 1.2432 - y2_output_root_mean_squared_error: 1.8779 - val_loss: 7.1586 - val_y1_output_loss: 1.4360 - val_y2_output_loss: 5.7226 - val_y1_output_root_mean_squared_error: 1.1983 - val_y2_output_root_mean_squared_error: 2.3922
# Epoch 75/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.0126 - y1_output_loss: 1.0724 - y2_output_loss: 2.9402 - y1_output_root_mean_squared_error: 1.0345 - y2_output_root_mean_squared_error: 1.7132 - val_loss: 7.1410 - val_y1_output_loss: 1.2210 - val_y2_output_loss: 5.9200 - val_y1_output_root_mean_squared_error: 1.1050 - val_y2_output_root_mean_squared_error: 2.4331
# Epoch 76/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.0714 - y1_output_loss: 1.2580 - y2_output_loss: 3.8134 - y1_output_root_mean_squared_error: 1.1119 - y2_output_root_mean_squared_error: 1.9383 - val_loss: 5.4522 - val_y1_output_loss: 0.9958 - val_y2_output_loss: 4.4565 - val_y1_output_root_mean_squared_error: 0.9979 - val_y2_output_root_mean_squared_error: 2.1110
# Epoch 77/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.0326 - y1_output_loss: 0.9994 - y2_output_loss: 3.0333 - y1_output_root_mean_squared_error: 0.9973 - y2_output_root_mean_squared_error: 1.7398 - val_loss: 4.9564 - val_y1_output_loss: 0.9329 - val_y2_output_loss: 4.0235 - val_y1_output_root_mean_squared_error: 0.9658 - val_y2_output_root_mean_squared_error: 2.0059
# Epoch 78/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.6115 - y1_output_loss: 1.1846 - y2_output_loss: 4.4269 - y1_output_root_mean_squared_error: 1.0878 - y2_output_root_mean_squared_error: 2.0986 - val_loss: 4.1261 - val_y1_output_loss: 1.0788 - val_y2_output_loss: 3.0473 - val_y1_output_root_mean_squared_error: 1.0387 - val_y2_output_root_mean_squared_error: 1.7457
# Epoch 79/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.7873 - y1_output_loss: 1.5550 - y2_output_loss: 4.2323 - y1_output_root_mean_squared_error: 1.2338 - y2_output_root_mean_squared_error: 2.0243 - val_loss: 8.3909 - val_y1_output_loss: 1.6641 - val_y2_output_loss: 6.7268 - val_y1_output_root_mean_squared_error: 1.2900 - val_y2_output_root_mean_squared_error: 2.5936
# Epoch 80/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.3166 - y1_output_loss: 0.8816 - y2_output_loss: 2.4350 - y1_output_root_mean_squared_error: 0.9355 - y2_output_root_mean_squared_error: 1.5596 - val_loss: 3.9365 - val_y1_output_loss: 0.8387 - val_y2_output_loss: 3.0978 - val_y1_output_root_mean_squared_error: 0.9158 - val_y2_output_root_mean_squared_error: 1.7601
# Epoch 81/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.7334 - y1_output_loss: 0.9577 - y2_output_loss: 2.7756 - y1_output_root_mean_squared_error: 0.9746 - y2_output_root_mean_squared_error: 1.6581 - val_loss: 4.3432 - val_y1_output_loss: 0.9174 - val_y2_output_loss: 3.4258 - val_y1_output_root_mean_squared_error: 0.9578 - val_y2_output_root_mean_squared_error: 1.8509
# Epoch 82/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.7637 - y1_output_loss: 1.3243 - y2_output_loss: 4.4394 - y1_output_root_mean_squared_error: 1.1404 - y2_output_root_mean_squared_error: 2.0754 - val_loss: 4.6525 - val_y1_output_loss: 0.9491 - val_y2_output_loss: 3.7034 - val_y1_output_root_mean_squared_error: 0.9742 - val_y2_output_root_mean_squared_error: 1.9244
# Epoch 83/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.4082 - y1_output_loss: 0.6830 - y2_output_loss: 2.7251 - y1_output_root_mean_squared_error: 0.8244 - y2_output_root_mean_squared_error: 1.6465 - val_loss: 3.7876 - val_y1_output_loss: 1.0318 - val_y2_output_loss: 2.7558 - val_y1_output_root_mean_squared_error: 1.0158 - val_y2_output_root_mean_squared_error: 1.6601
# Epoch 84/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.6862 - y1_output_loss: 1.5098 - y2_output_loss: 4.1764 - y1_output_root_mean_squared_error: 1.1742 - y2_output_root_mean_squared_error: 1.9936 - val_loss: 4.7512 - val_y1_output_loss: 1.4877 - val_y2_output_loss: 3.2635 - val_y1_output_root_mean_squared_error: 1.2197 - val_y2_output_root_mean_squared_error: 1.8065
# Epoch 85/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.5210 - y1_output_loss: 0.7530 - y2_output_loss: 2.7680 - y1_output_root_mean_squared_error: 0.8663 - y2_output_root_mean_squared_error: 1.6607 - val_loss: 4.0094 - val_y1_output_loss: 0.7667 - val_y2_output_loss: 3.2427 - val_y1_output_root_mean_squared_error: 0.8756 - val_y2_output_root_mean_squared_error: 1.8007
# Epoch 86/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.4931 - y1_output_loss: 0.9679 - y2_output_loss: 3.5251 - y1_output_root_mean_squared_error: 0.9830 - y2_output_root_mean_squared_error: 1.8706 - val_loss: 3.1197 - val_y1_output_loss: 0.8878 - val_y2_output_loss: 2.2320 - val_y1_output_root_mean_squared_error: 0.9422 - val_y2_output_root_mean_squared_error: 1.4940
# Epoch 87/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9585 - y1_output_loss: 0.6223 - y2_output_loss: 2.3362 - y1_output_root_mean_squared_error: 0.7883 - y2_output_root_mean_squared_error: 1.5271 - val_loss: 3.4758 - val_y1_output_loss: 0.7820 - val_y2_output_loss: 2.6938 - val_y1_output_root_mean_squared_error: 0.8843 - val_y2_output_root_mean_squared_error: 1.6413
# Epoch 88/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.2262 - y1_output_loss: 1.0911 - y2_output_loss: 3.1351 - y1_output_root_mean_squared_error: 1.0271 - y2_output_root_mean_squared_error: 1.7450 - val_loss: 8.3761 - val_y1_output_loss: 1.3884 - val_y2_output_loss: 6.9876 - val_y1_output_root_mean_squared_error: 1.1783 - val_y2_output_root_mean_squared_error: 2.6434
# Epoch 89/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.7568 - y1_output_loss: 0.7933 - y2_output_loss: 2.9635 - y1_output_root_mean_squared_error: 0.8826 - y2_output_root_mean_squared_error: 1.7101 - val_loss: 3.0895 - val_y1_output_loss: 0.7196 - val_y2_output_loss: 2.3699 - val_y1_output_root_mean_squared_error: 0.8483 - val_y2_output_root_mean_squared_error: 1.5394
# Epoch 90/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.2988 - y1_output_loss: 0.8790 - y2_output_loss: 3.4198 - y1_output_root_mean_squared_error: 0.9249 - y2_output_root_mean_squared_error: 1.8329 - val_loss: 4.0567 - val_y1_output_loss: 1.0608 - val_y2_output_loss: 2.9959 - val_y1_output_root_mean_squared_error: 1.0299 - val_y2_output_root_mean_squared_error: 1.7309
# Epoch 91/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.3768 - y1_output_loss: 0.9636 - y2_output_loss: 2.4132 - y1_output_root_mean_squared_error: 0.9737 - y2_output_root_mean_squared_error: 1.5470 - val_loss: 4.0602 - val_y1_output_loss: 1.3950 - val_y2_output_loss: 2.6653 - val_y1_output_root_mean_squared_error: 1.1811 - val_y2_output_root_mean_squared_error: 1.6326
# Epoch 92/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.2411 - y1_output_loss: 0.9222 - y2_output_loss: 2.3189 - y1_output_root_mean_squared_error: 0.9530 - y2_output_root_mean_squared_error: 1.5200 - val_loss: 4.9264 - val_y1_output_loss: 0.6469 - val_y2_output_loss: 4.2795 - val_y1_output_root_mean_squared_error: 0.8043 - val_y2_output_root_mean_squared_error: 2.0687
# Epoch 93/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.8151 - y1_output_loss: 0.8473 - y2_output_loss: 2.9678 - y1_output_root_mean_squared_error: 0.9029 - y2_output_root_mean_squared_error: 1.6920 - val_loss: 4.5647 - val_y1_output_loss: 0.9278 - val_y2_output_loss: 3.6369 - val_y1_output_root_mean_squared_error: 0.9632 - val_y2_output_root_mean_squared_error: 1.9071
# Epoch 94/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8943 - y1_output_loss: 0.6649 - y2_output_loss: 2.2293 - y1_output_root_mean_squared_error: 0.8146 - y2_output_root_mean_squared_error: 1.4882 - val_loss: 3.2302 - val_y1_output_loss: 0.8391 - val_y2_output_loss: 2.3911 - val_y1_output_root_mean_squared_error: 0.9160 - val_y2_output_root_mean_squared_error: 1.5463
# Epoch 95/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.0791 - y1_output_loss: 0.9284 - y2_output_loss: 3.1506 - y1_output_root_mean_squared_error: 0.9452 - y2_output_root_mean_squared_error: 1.7691 - val_loss: 3.4666 - val_y1_output_loss: 0.8018 - val_y2_output_loss: 2.6648 - val_y1_output_root_mean_squared_error: 0.8955 - val_y2_output_root_mean_squared_error: 1.6324
# Epoch 96/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8847 - y1_output_loss: 0.7030 - y2_output_loss: 2.1816 - y1_output_root_mean_squared_error: 0.8327 - y2_output_root_mean_squared_error: 1.4728 - val_loss: 6.5601 - val_y1_output_loss: 1.2729 - val_y2_output_loss: 5.2873 - val_y1_output_root_mean_squared_error: 1.1282 - val_y2_output_root_mean_squared_error: 2.2994
# Epoch 97/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8482 - y1_output_loss: 0.7244 - y2_output_loss: 2.1238 - y1_output_root_mean_squared_error: 0.8475 - y2_output_root_mean_squared_error: 1.4525 - val_loss: 10.0946 - val_y1_output_loss: 3.6015 - val_y2_output_loss: 6.4931 - val_y1_output_root_mean_squared_error: 1.8978 - val_y2_output_root_mean_squared_error: 2.5482
# Epoch 98/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.1153 - y1_output_loss: 1.2653 - y2_output_loss: 2.8500 - y1_output_root_mean_squared_error: 1.1061 - y2_output_root_mean_squared_error: 1.6833 - val_loss: 3.1050 - val_y1_output_loss: 0.6895 - val_y2_output_loss: 2.4155 - val_y1_output_root_mean_squared_error: 0.8304 - val_y2_output_root_mean_squared_error: 1.5542
# Epoch 99/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.0381 - y1_output_loss: 0.7259 - y2_output_loss: 2.3121 - y1_output_root_mean_squared_error: 0.8487 - y2_output_root_mean_squared_error: 1.5170 - val_loss: 6.2001 - val_y1_output_loss: 0.7990 - val_y2_output_loss: 5.4011 - val_y1_output_root_mean_squared_error: 0.8939 - val_y2_output_root_mean_squared_error: 2.3240
# Epoch 100/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.8088 - y1_output_loss: 0.9420 - y2_output_loss: 3.8668 - y1_output_root_mean_squared_error: 0.9579 - y2_output_root_mean_squared_error: 1.9206 - val_loss: 2.4159 - val_y1_output_loss: 0.4057 - val_y2_output_loss: 2.0102 - val_y1_output_root_mean_squared_error: 0.6369 - val_y2_output_root_mean_squared_error: 1.4178
# Epoch 101/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.6010 - y1_output_loss: 0.4490 - y2_output_loss: 2.1520 - y1_output_root_mean_squared_error: 0.6684 - y2_output_root_mean_squared_error: 1.4557 - val_loss: 3.1430 - val_y1_output_loss: 0.5862 - val_y2_output_loss: 2.5568 - val_y1_output_root_mean_squared_error: 0.7656 - val_y2_output_root_mean_squared_error: 1.5990
# Epoch 102/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6734 - y1_output_loss: 0.5637 - y2_output_loss: 2.1097 - y1_output_root_mean_squared_error: 0.7500 - y2_output_root_mean_squared_error: 1.4474 - val_loss: 2.6486 - val_y1_output_loss: 0.5093 - val_y2_output_loss: 2.1393 - val_y1_output_root_mean_squared_error: 0.7136 - val_y2_output_root_mean_squared_error: 1.4626
# Epoch 103/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.2202 - y1_output_loss: 0.8509 - y2_output_loss: 2.3694 - y1_output_root_mean_squared_error: 0.9108 - y2_output_root_mean_squared_error: 1.5165 - val_loss: 63.6541 - val_y1_output_loss: 23.9060 - val_y2_output_loss: 39.7481 - val_y1_output_root_mean_squared_error: 4.8894 - val_y2_output_root_mean_squared_error: 6.3046
# Epoch 104/500
# 62/62 [==============================] - 0s 2ms/step - loss: 10.8442 - y1_output_loss: 3.1268 - y2_output_loss: 7.7174 - y1_output_root_mean_squared_error: 1.6626 - y2_output_root_mean_squared_error: 2.6530 - val_loss: 3.1360 - val_y1_output_loss: 0.7291 - val_y2_output_loss: 2.4069 - val_y1_output_root_mean_squared_error: 0.8539 - val_y2_output_root_mean_squared_error: 1.5514
# Epoch 105/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.5936 - y1_output_loss: 0.5515 - y2_output_loss: 2.0421 - y1_output_root_mean_squared_error: 0.7398 - y2_output_root_mean_squared_error: 1.4265 - val_loss: 2.5943 - val_y1_output_loss: 0.4989 - val_y2_output_loss: 2.0954 - val_y1_output_root_mean_squared_error: 0.7063 - val_y2_output_root_mean_squared_error: 1.4475
# Epoch 106/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.8207 - y1_output_loss: 0.6503 - y2_output_loss: 2.1703 - y1_output_root_mean_squared_error: 0.8040 - y2_output_root_mean_squared_error: 1.4709 - val_loss: 6.1250 - val_y1_output_loss: 1.0454 - val_y2_output_loss: 5.0795 - val_y1_output_root_mean_squared_error: 1.0225 - val_y2_output_root_mean_squared_error: 2.2538
# Epoch 107/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9296 - y1_output_loss: 0.7635 - y2_output_loss: 2.1661 - y1_output_root_mean_squared_error: 0.8657 - y2_output_root_mean_squared_error: 1.4689 - val_loss: 2.5333 - val_y1_output_loss: 0.5747 - val_y2_output_loss: 1.9586 - val_y1_output_root_mean_squared_error: 0.7581 - val_y2_output_root_mean_squared_error: 1.3995
# Epoch 108/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.6663 - y1_output_loss: 0.6600 - y2_output_loss: 2.0063 - y1_output_root_mean_squared_error: 0.8102 - y2_output_root_mean_squared_error: 1.4050 - val_loss: 2.8635 - val_y1_output_loss: 0.4819 - val_y2_output_loss: 2.3816 - val_y1_output_root_mean_squared_error: 0.6942 - val_y2_output_root_mean_squared_error: 1.5433
# Epoch 109/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.7188 - y1_output_loss: 0.6063 - y2_output_loss: 2.1124 - y1_output_root_mean_squared_error: 0.7757 - y2_output_root_mean_squared_error: 1.4476 - val_loss: 2.4151 - val_y1_output_loss: 0.4765 - val_y2_output_loss: 1.9387 - val_y1_output_root_mean_squared_error: 0.6903 - val_y2_output_root_mean_squared_error: 1.3924
# Epoch 110/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.1141 - y1_output_loss: 0.6442 - y2_output_loss: 2.4700 - y1_output_root_mean_squared_error: 0.7959 - y2_output_root_mean_squared_error: 1.5582 - val_loss: 3.1669 - val_y1_output_loss: 0.6609 - val_y2_output_loss: 2.5060 - val_y1_output_root_mean_squared_error: 0.8130 - val_y2_output_root_mean_squared_error: 1.5830
# Epoch 111/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.3172 - y1_output_loss: 0.4363 - y2_output_loss: 1.8809 - y1_output_root_mean_squared_error: 0.6582 - y2_output_root_mean_squared_error: 1.3643 - val_loss: 7.5612 - val_y1_output_loss: 1.6703 - val_y2_output_loss: 5.8910 - val_y1_output_root_mean_squared_error: 1.2924 - val_y2_output_root_mean_squared_error: 2.4271
# Epoch 112/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.7978 - y1_output_loss: 0.6570 - y2_output_loss: 2.1408 - y1_output_root_mean_squared_error: 0.8087 - y2_output_root_mean_squared_error: 1.4526 - val_loss: 2.8540 - val_y1_output_loss: 0.5763 - val_y2_output_loss: 2.2777 - val_y1_output_root_mean_squared_error: 0.7592 - val_y2_output_root_mean_squared_error: 1.5092
# Epoch 113/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.5168 - y1_output_loss: 0.5512 - y2_output_loss: 1.9656 - y1_output_root_mean_squared_error: 0.7413 - y2_output_root_mean_squared_error: 1.3929 - val_loss: 5.3630 - val_y1_output_loss: 1.1518 - val_y2_output_loss: 4.2112 - val_y1_output_root_mean_squared_error: 1.0732 - val_y2_output_root_mean_squared_error: 2.0521
# Epoch 114/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.4763 - y1_output_loss: 0.8096 - y2_output_loss: 2.6667 - y1_output_root_mean_squared_error: 0.8941 - y2_output_root_mean_squared_error: 1.6235 - val_loss: 3.4849 - val_y1_output_loss: 0.7265 - val_y2_output_loss: 2.7583 - val_y1_output_root_mean_squared_error: 0.8524 - val_y2_output_root_mean_squared_error: 1.6608
# Epoch 115/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.7439 - y1_output_loss: 0.9620 - y2_output_loss: 2.7818 - y1_output_root_mean_squared_error: 0.9456 - y2_output_root_mean_squared_error: 1.6009 - val_loss: 4.3213 - val_y1_output_loss: 0.4786 - val_y2_output_loss: 3.8427 - val_y1_output_root_mean_squared_error: 0.6918 - val_y2_output_root_mean_squared_error: 1.9603
# Epoch 116/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.5376 - y1_output_loss: 0.6423 - y2_output_loss: 1.8954 - y1_output_root_mean_squared_error: 0.7966 - y2_output_root_mean_squared_error: 1.3749 - val_loss: 6.1777 - val_y1_output_loss: 0.8421 - val_y2_output_loss: 5.3356 - val_y1_output_root_mean_squared_error: 0.9177 - val_y2_output_root_mean_squared_error: 2.3099
# Epoch 117/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.9017 - y1_output_loss: 0.5206 - y2_output_loss: 2.3811 - y1_output_root_mean_squared_error: 0.7209 - y2_output_root_mean_squared_error: 1.5370 - val_loss: 2.1732 - val_y1_output_loss: 0.4454 - val_y2_output_loss: 1.7279 - val_y1_output_root_mean_squared_error: 0.6673 - val_y2_output_root_mean_squared_error: 1.3145
# Epoch 118/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.7613 - y1_output_loss: 0.6959 - y2_output_loss: 2.0655 - y1_output_root_mean_squared_error: 0.8249 - y2_output_root_mean_squared_error: 1.4330 - val_loss: 2.3770 - val_y1_output_loss: 0.4463 - val_y2_output_loss: 1.9307 - val_y1_output_root_mean_squared_error: 0.6681 - val_y2_output_root_mean_squared_error: 1.3895
# Epoch 119/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.3385 - y1_output_loss: 0.4624 - y2_output_loss: 1.8761 - y1_output_root_mean_squared_error: 0.6738 - y2_output_root_mean_squared_error: 1.3654 - val_loss: 2.5058 - val_y1_output_loss: 0.4437 - val_y2_output_loss: 2.0621 - val_y1_output_root_mean_squared_error: 0.6661 - val_y2_output_root_mean_squared_error: 1.4360
# Epoch 120/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.3737 - y1_output_loss: 0.4927 - y2_output_loss: 1.8810 - y1_output_root_mean_squared_error: 0.7012 - y2_output_root_mean_squared_error: 1.3706 - val_loss: 2.5588 - val_y1_output_loss: 0.6280 - val_y2_output_loss: 1.9309 - val_y1_output_root_mean_squared_error: 0.7924 - val_y2_output_root_mean_squared_error: 1.3896
# Epoch 121/500
# 62/62 [==============================] - 0s 2ms/step - loss: 2.0160 - y1_output_loss: 0.4484 - y2_output_loss: 1.5676 - y1_output_root_mean_squared_error: 0.6577 - y2_output_root_mean_squared_error: 1.2197 - val_loss: 4.6327 - val_y1_output_loss: 0.8675 - val_y2_output_loss: 3.7652 - val_y1_output_root_mean_squared_error: 0.9314 - val_y2_output_root_mean_squared_error: 1.9404
# Epoch 122/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2765 - y1_output_loss: 0.0949 - y2_output_loss: 0.1816 - y1_output_root_mean_squared_error: 0.3051 - y2_output_root_mean_squared_error: 0.4202 - val_loss: 1.2085 - val_y1_output_loss: 0.3623 - val_y2_output_loss: 0.8461 - val_y1_output_root_mean_squared_error: 0.6020 - val_y2_output_root_mean_squared_error: 0.9199
# Epoch 462/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4258 - y1_output_loss: 0.1460 - y2_output_loss: 0.2798 - y1_output_root_mean_squared_error: 0.3803 - y2_output_root_mean_squared_error: 0.5284 - val_loss: 0.9412 - val_y1_output_loss: 0.3049 - val_y2_output_loss: 0.6363 - val_y1_output_root_mean_squared_error: 0.5522 - val_y2_output_root_mean_squared_error: 0.7977
# Epoch 463/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2984 - y1_output_loss: 0.0936 - y2_output_loss: 0.2048 - y1_output_root_mean_squared_error: 0.3045 - y2_output_root_mean_squared_error: 0.4520 - val_loss: 1.0777 - val_y1_output_loss: 0.2928 - val_y2_output_loss: 0.7849 - val_y1_output_root_mean_squared_error: 0.5411 - val_y2_output_root_mean_squared_error: 0.8860
# Epoch 464/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3384 - y1_output_loss: 0.0993 - y2_output_loss: 0.2391 - y1_output_root_mean_squared_error: 0.3140 - y2_output_root_mean_squared_error: 0.4870 - val_loss: 0.8389 - val_y1_output_loss: 0.3033 - val_y2_output_loss: 0.5357 - val_y1_output_root_mean_squared_error: 0.5507 - val_y2_output_root_mean_squared_error: 0.7319
# Epoch 465/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.2893 - y1_output_loss: 0.1133 - y2_output_loss: 0.1760 - y1_output_root_mean_squared_error: 0.3354 - y2_output_root_mean_squared_error: 0.4182 - val_loss: 1.1706 - val_y1_output_loss: 0.3695 - val_y2_output_loss: 0.8011 - val_y1_output_root_mean_squared_error: 0.6079 - val_y2_output_root_mean_squared_error: 0.8950
# Epoch 466/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3329 - y1_output_loss: 0.0838 - y2_output_loss: 0.2491 - y1_output_root_mean_squared_error: 0.2882 - y2_output_root_mean_squared_error: 0.4958 - val_loss: 0.9311 - val_y1_output_loss: 0.2951 - val_y2_output_loss: 0.6360 - val_y1_output_root_mean_squared_error: 0.5432 - val_y2_output_root_mean_squared_error: 0.7975
# Epoch 467/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3918 - y1_output_loss: 0.1216 - y2_output_loss: 0.2701 - y1_output_root_mean_squared_error: 0.3477 - y2_output_root_mean_squared_error: 0.5162 - val_loss: 1.3669 - val_y1_output_loss: 0.4352 - val_y2_output_loss: 0.9317 - val_y1_output_root_mean_squared_error: 0.6597 - val_y2_output_root_mean_squared_error: 0.9652
# Epoch 468/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6521 - y1_output_loss: 0.1611 - y2_output_loss: 0.4910 - y1_output_root_mean_squared_error: 0.3974 - y2_output_root_mean_squared_error: 0.6904 - val_loss: 1.3788 - val_y1_output_loss: 0.3693 - val_y2_output_loss: 1.0095 - val_y1_output_root_mean_squared_error: 0.6077 - val_y2_output_root_mean_squared_error: 1.0047
# Epoch 469/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3998 - y1_output_loss: 0.1209 - y2_output_loss: 0.2789 - y1_output_root_mean_squared_error: 0.3469 - y2_output_root_mean_squared_error: 0.5263 - val_loss: 0.9206 - val_y1_output_loss: 0.2860 - val_y2_output_loss: 0.6346 - val_y1_output_root_mean_squared_error: 0.5348 - val_y2_output_root_mean_squared_error: 0.7966
# Epoch 470/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2928 - y1_output_loss: 0.0806 - y2_output_loss: 0.2122 - y1_output_root_mean_squared_error: 0.2834 - y2_output_root_mean_squared_error: 0.4600 - val_loss: 0.8740 - val_y1_output_loss: 0.2887 - val_y2_output_loss: 0.5853 - val_y1_output_root_mean_squared_error: 0.5373 - val_y2_output_root_mean_squared_error: 0.7650
# Epoch 471/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4039 - y1_output_loss: 0.1113 - y2_output_loss: 0.2926 - y1_output_root_mean_squared_error: 0.3314 - y2_output_root_mean_squared_error: 0.5368 - val_loss: 0.8090 - val_y1_output_loss: 0.2643 - val_y2_output_loss: 0.5447 - val_y1_output_root_mean_squared_error: 0.5141 - val_y2_output_root_mean_squared_error: 0.7380
# Epoch 472/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6225 - y1_output_loss: 0.1384 - y2_output_loss: 0.4841 - y1_output_root_mean_squared_error: 0.3697 - y2_output_root_mean_squared_error: 0.6828 - val_loss: 0.8800 - val_y1_output_loss: 0.2934 - val_y2_output_loss: 0.5866 - val_y1_output_root_mean_squared_error: 0.5416 - val_y2_output_root_mean_squared_error: 0.7659
# Epoch 473/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2914 - y1_output_loss: 0.0890 - y2_output_loss: 0.2024 - y1_output_root_mean_squared_error: 0.2978 - y2_output_root_mean_squared_error: 0.4485 - val_loss: 0.9920 - val_y1_output_loss: 0.2786 - val_y2_output_loss: 0.7135 - val_y1_output_root_mean_squared_error: 0.5278 - val_y2_output_root_mean_squared_error: 0.8447
# Epoch 474/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6491 - y1_output_loss: 0.1431 - y2_output_loss: 0.5059 - y1_output_root_mean_squared_error: 0.3757 - y2_output_root_mean_squared_error: 0.7002 - val_loss: 1.0322 - val_y1_output_loss: 0.2644 - val_y2_output_loss: 0.7677 - val_y1_output_root_mean_squared_error: 0.5142 - val_y2_output_root_mean_squared_error: 0.8762
# Epoch 475/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5548 - y1_output_loss: 0.1304 - y2_output_loss: 0.4245 - y1_output_root_mean_squared_error: 0.3608 - y2_output_root_mean_squared_error: 0.6485 - val_loss: 4.2555 - val_y1_output_loss: 0.8267 - val_y2_output_loss: 3.4288 - val_y1_output_root_mean_squared_error: 0.9092 - val_y2_output_root_mean_squared_error: 1.8517
# Epoch 476/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5399 - y1_output_loss: 0.1200 - y2_output_loss: 0.4199 - y1_output_root_mean_squared_error: 0.3431 - y2_output_root_mean_squared_error: 0.6165 - val_loss: 0.8543 - val_y1_output_loss: 0.2523 - val_y2_output_loss: 0.6020 - val_y1_output_root_mean_squared_error: 0.5023 - val_y2_output_root_mean_squared_error: 0.7759
# Epoch 477/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3071 - y1_output_loss: 0.0987 - y2_output_loss: 0.2084 - y1_output_root_mean_squared_error: 0.3130 - y2_output_root_mean_squared_error: 0.4560 - val_loss: 1.0529 - val_y1_output_loss: 0.3208 - val_y2_output_loss: 0.7321 - val_y1_output_root_mean_squared_error: 0.5664 - val_y2_output_root_mean_squared_error: 0.8556
# Epoch 478/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3564 - y1_output_loss: 0.1069 - y2_output_loss: 0.2495 - y1_output_root_mean_squared_error: 0.3260 - y2_output_root_mean_squared_error: 0.4963 - val_loss: 0.8060 - val_y1_output_loss: 0.2604 - val_y2_output_loss: 0.5456 - val_y1_output_root_mean_squared_error: 0.5103 - val_y2_output_root_mean_squared_error: 0.7386
# Epoch 479/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2558 - y1_output_loss: 0.0866 - y2_output_loss: 0.1692 - y1_output_root_mean_squared_error: 0.2936 - y2_output_root_mean_squared_error: 0.4106 - val_loss: 0.8314 - val_y1_output_loss: 0.2667 - val_y2_output_loss: 0.5648 - val_y1_output_root_mean_squared_error: 0.5164 - val_y2_output_root_mean_squared_error: 0.7515
# Epoch 480/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3278 - y1_output_loss: 0.1105 - y2_output_loss: 0.2173 - y1_output_root_mean_squared_error: 0.3304 - y2_output_root_mean_squared_error: 0.4629 - val_loss: 0.8802 - val_y1_output_loss: 0.3345 - val_y2_output_loss: 0.5457 - val_y1_output_root_mean_squared_error: 0.5783 - val_y2_output_root_mean_squared_error: 0.7387
# Epoch 481/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3537 - y1_output_loss: 0.1250 - y2_output_loss: 0.2287 - y1_output_root_mean_squared_error: 0.3529 - y2_output_root_mean_squared_error: 0.4772 - val_loss: 1.0887 - val_y1_output_loss: 0.3948 - val_y2_output_loss: 0.6940 - val_y1_output_root_mean_squared_error: 0.6283 - val_y2_output_root_mean_squared_error: 0.8330
# Epoch 482/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3763 - y1_output_loss: 0.1095 - y2_output_loss: 0.2667 - y1_output_root_mean_squared_error: 0.3303 - y2_output_root_mean_squared_error: 0.5149 - val_loss: 0.8060 - val_y1_output_loss: 0.2678 - val_y2_output_loss: 0.5382 - val_y1_output_root_mean_squared_error: 0.5175 - val_y2_output_root_mean_squared_error: 0.7336
# Epoch 483/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2457 - y1_output_loss: 0.0829 - y2_output_loss: 0.1628 - y1_output_root_mean_squared_error: 0.2857 - y2_output_root_mean_squared_error: 0.3970 - val_loss: 2.6043 - val_y1_output_loss: 0.3156 - val_y2_output_loss: 2.2887 - val_y1_output_root_mean_squared_error: 0.5618 - val_y2_output_root_mean_squared_error: 1.5128
# Epoch 484/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5200 - y1_output_loss: 0.1200 - y2_output_loss: 0.4001 - y1_output_root_mean_squared_error: 0.3461 - y2_output_root_mean_squared_error: 0.6225 - val_loss: 2.7445 - val_y1_output_loss: 0.4473 - val_y2_output_loss: 2.2972 - val_y1_output_root_mean_squared_error: 0.6688 - val_y2_output_root_mean_squared_error: 1.5156
# Epoch 485/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5503 - y1_output_loss: 0.1527 - y2_output_loss: 0.3976 - y1_output_root_mean_squared_error: 0.3830 - y2_output_root_mean_squared_error: 0.6214 - val_loss: 0.9427 - val_y1_output_loss: 0.2885 - val_y2_output_loss: 0.6542 - val_y1_output_root_mean_squared_error: 0.5371 - val_y2_output_root_mean_squared_error: 0.8088
# Epoch 486/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3365 - y1_output_loss: 0.1115 - y2_output_loss: 0.2250 - y1_output_root_mean_squared_error: 0.3328 - y2_output_root_mean_squared_error: 0.4737 - val_loss: 0.9990 - val_y1_output_loss: 0.3022 - val_y2_output_loss: 0.6968 - val_y1_output_root_mean_squared_error: 0.5497 - val_y2_output_root_mean_squared_error: 0.8347
# Epoch 487/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3144 - y1_output_loss: 0.1003 - y2_output_loss: 0.2141 - y1_output_root_mean_squared_error: 0.3157 - y2_output_root_mean_squared_error: 0.4608 - val_loss: 1.1301 - val_y1_output_loss: 0.3238 - val_y2_output_loss: 0.8063 - val_y1_output_root_mean_squared_error: 0.5690 - val_y2_output_root_mean_squared_error: 0.8980
# Epoch 488/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4150 - y1_output_loss: 0.1058 - y2_output_loss: 0.3093 - y1_output_root_mean_squared_error: 0.3249 - y2_output_root_mean_squared_error: 0.5551 - val_loss: 1.4391 - val_y1_output_loss: 0.4582 - val_y2_output_loss: 0.9810 - val_y1_output_root_mean_squared_error: 0.6769 - val_y2_output_root_mean_squared_error: 0.9904
# Epoch 489/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4796 - y1_output_loss: 0.1459 - y2_output_loss: 0.3337 - y1_output_root_mean_squared_error: 0.3798 - y2_output_root_mean_squared_error: 0.5740 - val_loss: 1.0065 - val_y1_output_loss: 0.2769 - val_y2_output_loss: 0.7296 - val_y1_output_root_mean_squared_error: 0.5262 - val_y2_output_root_mean_squared_error: 0.8542
# Epoch 490/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3469 - y1_output_loss: 0.0957 - y2_output_loss: 0.2512 - y1_output_root_mean_squared_error: 0.3085 - y2_output_root_mean_squared_error: 0.5006 - val_loss: 0.8064 - val_y1_output_loss: 0.2587 - val_y2_output_loss: 0.5477 - val_y1_output_root_mean_squared_error: 0.5087 - val_y2_output_root_mean_squared_error: 0.7401
# Epoch 491/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3116 - y1_output_loss: 0.1060 - y2_output_loss: 0.2056 - y1_output_root_mean_squared_error: 0.3247 - y2_output_root_mean_squared_error: 0.4508 - val_loss: 0.7826 - val_y1_output_loss: 0.2753 - val_y2_output_loss: 0.5073 - val_y1_output_root_mean_squared_error: 0.5247 - val_y2_output_root_mean_squared_error: 0.7123
# Epoch 492/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3958 - y1_output_loss: 0.1209 - y2_output_loss: 0.2748 - y1_output_root_mean_squared_error: 0.3471 - y2_output_root_mean_squared_error: 0.5157 - val_loss: 1.6614 - val_y1_output_loss: 0.3171 - val_y2_output_loss: 1.3444 - val_y1_output_root_mean_squared_error: 0.5631 - val_y2_output_root_mean_squared_error: 1.1595
# Epoch 493/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4163 - y1_output_loss: 0.1104 - y2_output_loss: 0.3059 - y1_output_root_mean_squared_error: 0.3319 - y2_output_root_mean_squared_error: 0.5437 - val_loss: 0.8805 - val_y1_output_loss: 0.2530 - val_y2_output_loss: 0.6275 - val_y1_output_root_mean_squared_error: 0.5029 - val_y2_output_root_mean_squared_error: 0.7921
# Epoch 494/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.3367 - y1_output_loss: 0.1107 - y2_output_loss: 0.2259 - y1_output_root_mean_squared_error: 0.3309 - y2_output_root_mean_squared_error: 0.4677 - val_loss: 0.8901 - val_y1_output_loss: 0.3213 - val_y2_output_loss: 0.5688 - val_y1_output_root_mean_squared_error: 0.5668 - val_y2_output_root_mean_squared_error: 0.7542
# Epoch 495/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3997 - y1_output_loss: 0.1018 - y2_output_loss: 0.2979 - y1_output_root_mean_squared_error: 0.3165 - y2_output_root_mean_squared_error: 0.5399 - val_loss: 0.9412 - val_y1_output_loss: 0.3774 - val_y2_output_loss: 0.5638 - val_y1_output_root_mean_squared_error: 0.6143 - val_y2_output_root_mean_squared_error: 0.7509
# Epoch 496/500
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4516 - y1_output_loss: 0.1119 - y2_output_loss: 0.3397 - y1_output_root_mean_squared_error: 0.3340 - y2_output_root_mean_squared_error: 0.5796 - val_loss: 1.0206 - val_y1_output_loss: 0.3214 - val_y2_output_loss: 0.6992 - val_y1_output_root_mean_squared_error: 0.5669 - val_y2_output_root_mean_squared_error: 0.8362
# Epoch 497/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3377 - y1_output_loss: 0.1037 - y2_output_loss: 0.2340 - y1_output_root_mean_squared_error: 0.3214 - y2_output_root_mean_squared_error: 0.4769 - val_loss: 0.9286 - val_y1_output_loss: 0.3200 - val_y2_output_loss: 0.6086 - val_y1_output_root_mean_squared_error: 0.5656 - val_y2_output_root_mean_squared_error: 0.7801
# Epoch 498/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3883 - y1_output_loss: 0.1286 - y2_output_loss: 0.2597 - y1_output_root_mean_squared_error: 0.3576 - y2_output_root_mean_squared_error: 0.5085 - val_loss: 0.8749 - val_y1_output_loss: 0.2609 - val_y2_output_loss: 0.6141 - val_y1_output_root_mean_squared_error: 0.5107 - val_y2_output_root_mean_squared_error: 0.7836
# Epoch 499/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3185 - y1_output_loss: 0.0942 - y2_output_loss: 0.2243 - y1_output_root_mean_squared_error: 0.3060 - y2_output_root_mean_squared_error: 0.4723 - val_loss: 3.4203 - val_y1_output_loss: 1.1733 - val_y2_output_loss: 2.2470 - val_y1_output_root_mean_squared_error: 1.0832 - val_y2_output_root_mean_squared_error: 1.4990
# Epoch 500/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7310 - y1_output_loss: 0.2134 - y2_output_loss: 0.5176 - y1_output_root_mean_squared_error: 0.4455 - y2_output_root_mean_squared_error: 0.7044 - val_loss: 0.9281 - val_y1_output_loss: 0.2502 - val_y2_output_loss: 0.6779 - val_y1_output_root_mean_squared_error: 0.5002 - val_y2_output_root_mean_squared_error: 0.8234

# %% [markdown]
# # Evaluate Model and Plot Metrics

# %%
# Evaluate
# - print loss and rmse for both outputs
# loss is y1_output_loss + y2_output_loss

loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x = norm_test_X, y = test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.9281 - y1_output_loss: 0.2502 - y2_output_loss: 0.6779 - y1_output_root_mean_squared_error: 0.5002 - y2_output_root_mean_squared_error: 0.8234
# Loss = 0.9281019568443298, Y1_loss = 0.25018593668937683, Y1_mse = 0.5001859068870544, Y2_loss = 0.6779160499572754, Y2_mse = 0.823356568813324

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
